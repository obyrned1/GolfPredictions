# %%
#import packages required
import requests
import pandas as pd
from bs4 import BeautifulSoup
import csv
import numpy as np
from functools import reduce
import urllib
import urllib.request as ur

# %%
#categories of stats available 

categories = {"Off the tee":"ROTT","Approach the green":"RAPP","Around the green":"RARG","Putting":"RPUT",
              'Scoring':"RSCR","Streaks":"RSTR","Money/Finishes":"RMNY","Points/Rankings":"RPTS"}
print ("Breakdown of statistics categories:")
for key in categories:
    print (key)
# Out:
# Breakdown of statistics categories:
# Off the tee
# Approach the green
# Around the green
# Putting
# Scoring
# Streaks
# Money/Finishes
# Points/Rankings

# %%
def category_links(category):
    
    pga_link = "http://www.pgatour.com/stats/categories."+categories[category]+"_INQ.html"
    pga_link = ur.urlopen(pga_link)
    soup = BeautifulSoup(pga_link,'lxml')
    links = []
    clean_links = {}

    for element in soup.find_all('div',class_="table-content clearfix"):
        for link in element.findAll('a'):
            test = link.get('href')
            clean_links[link.find(text=True)] = test.replace("/content/pgatour", "http://www.pgatour.com")

    return clean_links;

# %%
#input your category and will return stats available with corresponding link
#enter catregory in inverted commas, eg "Scoring"

category_links("Approach the green")
# Out:
# {'Approach 100-125 yards (RTP Score)': 'http://www.pgatour.com/stats/stat.028.html',
#  'Approach 125-150 yards (RTP Score)': 'http://www.pgatour.com/stats/stat.473.html',
#  'Approach 150-175 yards (RTP Score)': 'http://www.pgatour.com/stats/stat.478.html',
#  'Approach 175-200 yards (RTP Score)': 'http://www.pgatour.com/stats/stat.479.html',
#  'Approach 200-225 yards (RTP)': 'http://www.pgatour.com/stats/stat.02376.html',
#  'Approach 225-250 yards (RTP)': 'http://www.pgatour.com/stats/stat.02377.html',
#  'Approach 250-275 yards (RTP)': 'http://www.pgatour.com/stats/stat.02378.html',
#  'Approach 50-75 yards (RTP Score)': 'http://www.pgatour.com/stats/stat.030.html',
#  'Approach 75-100 yards (RTP Score)': 'http://www.pgatour.com/stats/stat.029.html',
#  'Approach < 125 yards (RTP Score)': 'http://www.pgatour.com/stats/stat.472.html',
#  'Approach > 200 yards (RTP Score)': 'http://www.pgatour.com/stats/stat.480.html',
#  'Approach > 275 yards (RTP)': 'http://www.pgatour.com/stats/stat.02379.html',
#  'Approaches 100-125 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02382.html',
#  'Approaches 125-150 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02384.html',
#  'Approaches 150-175 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02385.html',
#  'Approaches 175-200 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02386.html',
#  'Approaches 200-225 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02390.html',
#  'Approaches 225-250 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02391.html',
#  'Approaches 250-275 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02392.html',
#  'Approaches 50-125 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02383.html',
#  'Approaches 50-75 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02380.html',
#  'Approaches 75-100 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02381.html',
#  'Approaches < 100 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02388.html',
#  'Approaches > 100 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02389.html',
#  'Approaches > 200 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02387.html',
#  'Approaches > 275 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02393.html',
#  'Approaches Left Rough (RTP Score)': 'http://www.pgatour.com/stats/stat.469.html',
#  'Approaches Right Rough (RTP Score)': 'http://www.pgatour.com/stats/stat.470.html',
#  'Approaches from 100-125 yards': 'http://www.pgatour.com/stats/stat.074.html',
#  'Approaches from 100-125 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02364.html',
#  'Approaches from 125-150 yards': 'http://www.pgatour.com/stats/stat.339.html',
#  'Approaches from 125-150 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02366.html',
#  'Approaches from 150-175 yards': 'http://www.pgatour.com/stats/stat.338.html',
#  'Approaches from 150-175 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02367.html',
#  'Approaches from 175-200 yards': 'http://www.pgatour.com/stats/stat.337.html',
#  'Approaches from 175-200 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02368.html',
#  'Approaches from 200-225 yards': 'http://www.pgatour.com/stats/stat.02358.html',
#  'Approaches from 200-225 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02372.html',
#  'Approaches from 225-250 yards': 'http://www.pgatour.com/stats/stat.02359.html',
#  'Approaches from 225-250 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02373.html',
#  'Approaches from 250-275 yards': 'http://www.pgatour.com/stats/stat.02360.html',
#  'Approaches from 250-275 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02374.html',
#  'Approaches from 50-125 yards': 'http://www.pgatour.com/stats/stat.340.html',
#  'Approaches from 50-125 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02365.html',
#  'Approaches from 50-75 yards': 'http://www.pgatour.com/stats/stat.076.html',
#  'Approaches from 50-75 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02362.html',
#  'Approaches from 75-100 yards': 'http://www.pgatour.com/stats/stat.075.html',
#  'Approaches from 75-100 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02363.html',
#  'Approaches from > 100 yards': 'http://www.pgatour.com/stats/stat.02331.html',
#  'Approaches from > 100 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02371.html',
#  'Approaches from > 200 yards': 'http://www.pgatour.com/stats/stat.336.html',
#  'Approaches from > 200 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02369.html',
#  'Approaches from > 275 yards': 'http://www.pgatour.com/stats/stat.02361.html',
#  'Approaches from > 275 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02375.html',
#  'Approaches from inside 100 yards': 'http://www.pgatour.com/stats/stat.02329.html',
#  'Approaches from inside 100 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02370.html',
#  'Average Approach Distance - Birdie or Better': 'http://www.pgatour.com/stats/stat.02338.html',
#  'Average Approach Distance - Bogey or Worse': 'http://www.pgatour.com/stats/stat.02340.html',
#  'Average Approach Distance - Par': 'http://www.pgatour.com/stats/stat.02339.html',
#  'Average Approach Shot Distance': 'http://www.pgatour.com/stats/stat.02325.html',
#  'Average Distance after Going for it Shot': 'http://www.pgatour.com/stats/stat.02431.html',
#  'Average Distance to Hole After Tee Shot': 'http://www.pgatour.com/stats/stat.02430.html',
#  'Average Going for it Shot Distance (in Yards)': 'http://www.pgatour.com/stats/stat.02426.html',
#  'Birdie or Better Percentage - 125-150 ya': 'http://www.pgatour.com/stats/stat.360.html',
#  'Birdie or Better Percentage - 150-175 ya': 'http://www.pgatour.com/stats/stat.359.html',
#  'Birdie or Better Percentage - 175-200 ya': 'http://www.pgatour.com/stats/stat.358.html',
#  'Birdie or Better Percentage - 200+ yards': 'http://www.pgatour.com/stats/stat.357.html',
#  'Birdie or Better Percentage - < 125 yard': 'http://www.pgatour.com/stats/stat.361.html',
#  'Birdie or Better Percentage - Fairway': 'http://www.pgatour.com/stats/stat.02333.html',
#  'Birdie or Better Percentage - Left Rough': 'http://www.pgatour.com/stats/stat.02334.html',
#  'Birdie or Better Percentage - Right Rough': 'http://www.pgatour.com/stats/stat.02335.html',
#  'Birdie or Better Percentage - Rough': 'http://www.pgatour.com/stats/stat.02336.html',
#  'Fairway Approach (RTP Score)': 'http://www.pgatour.com/stats/stat.471.html',
#  'Fairway Proximity': 'http://www.pgatour.com/stats/stat.431.html',
#  'GIR Pct. - Fairway Bunker': 'http://www.pgatour.com/stats/stat.02434.html',
#  'GIR Percentage - 100+ yards': 'http://www.pgatour.com/stats/stat.02332.html',
#  'GIR Percentage - 100-125 yards': 'http://www.pgatour.com/stats/stat.077.html',
#  'GIR Percentage - 125-150 yards': 'http://www.pgatour.com/stats/stat.329.html',
#  'GIR Percentage - 150-175 yards': 'http://www.pgatour.com/stats/stat.328.html',
#  'GIR Percentage - 175-200 yards': 'http://www.pgatour.com/stats/stat.327.html',
#  'GIR Percentage - 200+ yards': 'http://www.pgatour.com/stats/stat.326.html',
#  'GIR Percentage - 75-100 yards': 'http://www.pgatour.com/stats/stat.078.html',
#  'GIR Percentage - < 100 yards': 'http://www.pgatour.com/stats/stat.02330.html',
#  'GIR Percentage - < 125 yards': 'http://www.pgatour.com/stats/stat.330.html',
#  'GIR Percentage - < 75 yards': 'http://www.pgatour.com/stats/stat.079.html',
#  'GIR Percentage from Fairway': 'http://www.pgatour.com/stats/stat.190.html',
#  'GIR Percentage from Other than Fairway': 'http://www.pgatour.com/stats/stat.199.html',
#  'Going for the Green': 'http://www.pgatour.com/stats/stat.419.html',
#  'Going for the Green - Birdie or Better': 'http://www.pgatour.com/stats/stat.02357.html',
#  'Going for the Green - Hit Green Pct.': 'http://www.pgatour.com/stats/stat.486.html',
#  'Greens in Regulation Percentage': 'http://www.pgatour.com/stats/stat.103.html',
#  'Greens or Fringe in Regulation': 'http://www.pgatour.com/stats/stat.02437.html',
#  'Left Rough Proximity': 'http://www.pgatour.com/stats/stat.432.html',
#  'Longest Hole Outs (in yards)': 'http://www.pgatour.com/stats/stat.351.html',
#  'Par 5 Going for the Green': 'http://www.pgatour.com/stats/stat.436.html',
#  'Proximity to Hole': 'http://www.pgatour.com/stats/stat.331.html',
#  'Right Rough Proximity': 'http://www.pgatour.com/stats/stat.433.html',
#  'Rough Proximity': 'http://www.pgatour.com/stats/stat.437.html',
#  'SG: Approach-the-Green': 'http://www.pgatour.com/stats/stat.02568.html',
#  'Total Hole Outs': 'http://www.pgatour.com/stats/stat.350.html'}

# %%
#put all urls for the stats in here
urls = [ 
    "https://www.pgatour.com/stats/stat.02567.html", 
    "https://www.pgatour.com/stats/stat.02674.html",
    "https://www.pgatour.com/stats/stat.142.html",
    "http://www.pgatour.com/stats/stat.143.html",
    "http://www.pgatour.com/stats/stat.158.html",
    "https://www.pgatour.com/stats/stat.102.html",
    "https://www.pgatour.com/stats/stat.02428.html",
    "https://www.pgatour.com/stats/stat.130.html",
    "https://www.pgatour.com/stats/stat.02569.html",
    "https://www.pgatour.com/stats/stat.437.html",
    "https://www.pgatour.com/stats/stat.360.html"]

#these are the names of the stats, just copy and paste these into columnNames below
stats = [ 'SGoffTheTee','SGteeToGreen',"Par3 Scoring_Avergage",
         "Par4 Scoring_Avergage","Ball Striking","Driving Accuracy",
         "Total Putting","Scrambling", "SG:AroundTheGreen",
         "Rough Proximity","Birdie/Better_125-150"]

columnNames = [ "Player",'SGoffTheTee',  'SGteeToGreen',
         "Par3 Scoring_Avergage","Par4 Scoring_Avergage","Ball Striking",
        "Driving Accuracy","Total Putting","Scrambling",
        "SG:AroundTheGreen","Rough Proximity","Birdie/Better_125-150"]
#weights need to be in the correct order for the stats above
weights = [1,1,1,1,3,3,2,2,1,1,1]

stats
# Out:
# ['SGoffTheTee',
#  'SGteeToGreen',
#  'Par3 Scoring_Avergage',
#  'Par4 Scoring_Avergage',
#  'Ball Striking',
#  'Driving Accuracy',
#  'Total Putting',
#  'Scrambling',
#  'SG:AroundTheGreen',
#  'Rough Proximity',
#  'Birdie/Better_125-150']

# %%
#function to call the players name and associated rank for each stat
def scrape_money_leaders(url):
  response = requests.get(url)
  soup = BeautifulSoup(response.content, 'lxml')
  money = []
  for item in soup.findAll("td", "player-name"):
      money.append(item.text)
  return money

# %%
#empty array dfs which will store a dataframe for each stat
dfs = []

for i in range(0,len(urls)):
    stats[i] = scrape_money_leaders(urls[i])
    columns = ['Player']
    stats[i] = pd.DataFrame(stats[i],columns=columns)
    stats[i].insert(1, 'Rank', range(1, 1 + len(stats[i])))
    dfs.append(stats[i])

#then merge each of the dataframes on the equality of the player name
#this means each player will have their name, then their associcated stats in one dataframe
df_final = reduce(lambda left,right: pd.merge(left,right,on='Player'), dfs)
df_final.columns = columnNames

#this loops throguh each feature and multiplies by by the relevant weight
for i in range(1, len(columnNames)-1):
    df_final[columnNames[i]] = df_final[columnNames[i]]*weights[i-1]

#add the contents of each column to give a total for each player
df_final['Total'] = df_final.sum(axis=1)

#sorts these totals so the lowest totals are at the top
df_stats = df_final.sort_values(by='Total', ascending=True)
df_stats = df_stats.replace(to_replace=r'\n', value='', regex=True)

# %%
#temporary scrape of field list - will look to generalise this
field_link = "http://www.deananddelucainvitational.com/players/committed-players"
field_page = ur.urlopen(field_link)
field_soup = BeautifulSoup(field_page,'lxml')

player_list = field_soup.find_all("span", class_="field-content")

field =[]

for player in  player_list:
    field.append(player.text)
    
field = pd.DataFrame(data=field)
field.columns = ["Player"]

field = field.replace(to_replace=r'  ', value=' ', regex=True)

# %%
#stats of players playing in the event
df_predictions = pd.merge(field,df_stats,on="Player")
df_predictions = df_predictions.sort_values(by='Total', ascending=True)
df_predictions
# Out:
#                  Player  SGoffTheTee  SGteeToGreen  Par3 Scoring_Avergage  \
# 75          Chez Reavie           48            40                      4
# 27      Emiliano Grillo           25            24                      8
# 94      Kevin Streelman           22            15                    108
# 90        Jordan Spieth           18             2                     52
# 77          Justin Rose           21            30                     92
# 22        Rickie Fowler           63            28                     58
# 39         Zach Johnson           89            23                      3
# 13          Austin Cook           77            87                      6
# 32         Brian Harman           60            81                    132
# 16    Bryson DeChambeau           14            12                    113
# 44           Chris Kirk          102            31                     21
# 47         Russell Knox           81            53                    135
# 52         Martin Laird           94            62                    136
# 74             Jon Rahm            2            25                     47
# 14            Ben Crane          177           147                     55
# 36         Beau Hossler           52           110                     60
# 15          Joel Dahmen           76           109                    101
# 29       Chesson Hadley           99            32                      9
# 86         Webb Simpson           95            33                     77
# 88      Brandt Snedeker          122           116                     78
# 30          Adam Hadwin          108            34                     59
# 78       Rory Sabbatini           70            67                    141
# 106          Aaron Wise           33            58                    110
# 50          Matt Kuchar          134            91                    118
# 98        Vaughn Taylor          107            93                     66
# 68            Pat Perez           79            60                     75
# 38             John Huh          111           112                     20
# 69         Scott Piercy           65            11                    122
# 96         Brian Stuard          156           132                     95
# 67             C.T. Pan           74            94                    121
# ..                  ...          ...           ...                    ...
# 7         Jonathan Byrd          178           130                     68
# 34      Charley Hoffman           55            54                    172
# 91      Scott Stallings          146           101                     65
# 28            Bill Haas          129            75                     70
# 31      Brandon Harkins           72            71                     33
# 4           Scott Brown          166           166                     84
# 61       Grayson Murray           35            59                    154
# 51       Anirban Lahiri          123           150                     74
# 101  Tyrone Van Aswegen          181           145                     15
# 100          Kevin Tway           59            80                    126
# 6             Sam Burns           69           106                    148
# 2        Aaron Baddeley          167            61                    112
# 85        Ben Silverman          144           164                    142
# 92        Shawn Stefani          160           126                     79
# 102     Jhonattan Vegas           62            96                    166
# 54            Danny Lee          176           165                     13
# 11         Stewart Cink          100            69                    168
# 95         Chris Stroud          191           172                    163
# 24      Robert Garrigus          121            82                     31
# 57         Tom Lovelady           17           123                    188
# 5          Wesley Bryan          208           193                     99
# 70        Martin Piller          145           191                    123
# 42             Whee Kim          198           200                    152
# 21        Martin Flores          130           125                     86
# 26         Cody Gribble          171           195                    181
# 40            Sung Kang          188           176                     34
# 93         Robert Streb          192           167                    192
# 20       Derek Fathauer          197           197                     44
# 37     Mackenzie Hughes          151           153                    200
# 41       Smylie Kaufman          207           208                    208
#
#      Par4 Scoring_Avergage  Ball Striking  Driving Accuracy  Total Putting  \
# 75                      11            129                 9             68
# 27                      17             21                51             74
# 94                      16             18                60            330
# 90                       8             51               255            394
# 77                       7             36               249            162
# 22                       5             39               165            300
# 39                      20            276               228            148
# 13                      74            243               129             20
# 32                      19            111                63            184
# 16                      30             30               240            172
# 44                      61            225               171            208
# 47                      34             72               108            308
# 52                      63            177               210            138
# 74                       6             75               387            134
# 14                      42            375                54             34
# 36                      45            156               345            108
# 15                      29            162                87            316
# 29                      18            210               411             10
# 86                      12            399               342              8
# 88                      51            345               105            130
# 30                      44            201               174            142
# 78                      36            297               246            168
# 106                     27             96               270            104
# 50                      21            327               231             92
# 98                     105            291                69            144
# 68                      22             45                30            366
# 38                      78            342               144             28
# 69                      14            138               186            398
# 96                      88            279                12             90
# 67                     117             42                42            262
# ..                     ...            ...               ...            ...
# 7                      110            411               372            370
# 34                      60            351               543            294
# 91                     119            534               561            156
# 28                     145            474               501            328
# 31                      96            372               606            284
# 4                       72            423               330            200
# 61                      83            306               486            362
# 51                     129            456               354            212
# 101                    154            528               471            106
# 100                    153            258               570            258
# 6                      109            348               609              6
# 2                       54            576               585            358
# 85                     180            477               219            174
# 92                     151            492               558            122
# 102                    136            408               432            386
# 54                     171            540               285             82
# 11                      56            324               525            288
# 95                     166            555               225            240
# 24                     126            300               510            406
# 57                     113            261               567            278
# 5                      139            600               489             54
# 70                     185            582               438            176
# 42                     170            579               420             96
# 21                     142            468               564            384
# 26                     177            489               483            114
# 40                     194            519               492            236
# 93                     186            570               549            302
# 20                     197            618               600            256
# 37                     146            564               468            346
# 41                     208            603               624            264
#
#      Scrambling  SG:AroundTheGreen  Rough Proximity  Birdie/Better_125-150  \
# 75           26                130               56                     21
# 27          100                129              200                      1
# 94           20                 43                4                    124
# 90            6                 13               13                      4
# 77           52                 54               67                     53
# 22           12                 26              180                     12
# 39           84                 29               51                      7
# 13           86                 44               31                    169
# 32          178                112                5                     37
# 16          200                106               60                     59
# 44           22                 21               87                     91
# 47          142                 58               70                     55
# 52          136                 18               26                     84
# 74          152                 68               94                    163
# 14           60                 64               59                    102
# 36          138                 74               11                     73
# 15           62                118               12                    134
# 29          244                122               18                     44
# 86            2                 24              153                     78
# 88           38                 63              116                     62
# 30          256                 22               45                    154
# 78           58                 19                9                    143
# 106         274                116              106                     64
# 50           66                 71               19                     96
# 98          106                113               92                    110
# 68          366                 85              160                     15
# 38          176                140              145                     34
# 69          246                 90               25                     67
# 96          212                103              103                    107
# 67          322                105               28                    184
# ..          ...                ...              ...                    ...
# 7           134                 14               69                    181
# 34          314                142               38                     17
# 91           56                102               71                    139
# 28          124                 31              105                     93
# 31          250                155              107                     50
# 4           210                 96              181                    173
# 61          326                 89               54                    148
# 51          252                 62              150                    155
# 101         222                 55              149                    126
# 100         318                139              109                     89
# 6           330                196              185                     54
# 2            42                  2               55                    149
# 85          278                149              193                     47
# 92          116                 75              126                    185
# 102         150                156              188                     18
# 54          342                133              164                    150
# 11          382                191               16                    117
# 95          148                141              158                     80
# 24          338                153              114                     72
# 57          378                204               36                    118
# 5           264                 40              171                     38
# 70          196                145               81                    122
# 42          234                174              186                      6
# 21          288                143              104                    200
# 26          386                138              207                    133
# 40          374                152              205                    141
# 93          362                 48              178                     45
# 20          334                125               49                    192
# 37          370                181              156                     90
# 41          408                202               46                    121
#
#      Total
# 75     542
# 27     650
# 94     760
# 90     816
# 77     823
# 22     888
# 39     958
# 13     966
# 32     982
# 16    1036
# 44    1040
# 47    1116
# 52    1144
# 74    1153
# 14    1169
# 36    1172
# 15    1206
# 29    1217
# 86    1223
# 88    1226
# 30    1239
# 78    1254
# 106   1258
# 50    1266
# 98    1296
# 68    1303
# 38    1330
# 69    1362
# 96    1377
# 67    1391
# ..     ...
# 7     2037
# 34    2040
# 91    2050
# 28    2075
# 31    2096
# 4     2101
# 61    2102
# 51    2117
# 101   2152
# 100   2159
# 6     2160
# 2     2161
# 85    2167
# 92    2190
# 102   2198
# 54    2221
# 11    2236
# 95    2239
# 24    2253
# 57    2283
# 5     2295
# 70    2384
# 42    2415
# 21    2634
# 26    2674
# 40    2711
# 93    2791
# 20    2809
# 37    2825
# 41    3099
#
# [108 rows x 13 columns]

# %%
df_predictions.isnull().any().any()
# Out:
# False

# %%
#players in the field we dont have stats for
field_players = set(field["Player"])
stats_players = set(df_stats["Player"])

print(field_players - stats_players)
# Out:
# {'David     Hearn', 'John Senden', 'Keith Clearwater', 'Brooks Koepka', 'Maverick McNealy', 'Joaquin Niemann', 'Shubhankar Sharma', 'Satoshi Kodaira', 'J. J. Henry', 'Jim Furyk', 'Steve Stricker', 'Tim Herron', 'Ted Potter Jr.'}

# %%
#search for player within field
df_predictions.loc[df_predictions['Player'] == "Brooks Koepka"]
# Out:
# Empty DataFrame
# Columns: [Player, SGoffTheTee, SGteeToGreen, Par3 Scoring_Avergage, Par4 Scoring_Avergage, Ball Striking, Driving Accuracy, Total Putting, Scrambling, SG:AroundTheGreen, Rough Proximity, Birdie/Better_125-150, Total]
# Index: []

# %%
#search for player outside of field
df_stats.loc[df_stats['Player'] == "Ted Potter, Jr."]
# Out:
#               Player  SGoffTheTee  SGteeToGreen  Par3 Scoring_Avergage  \
# 123  Ted Potter, Jr.          124           129                    190
#
#      Par4 Scoring_Avergage  Ball Striking  Driving Accuracy  Total Putting  \
# 123                    165            507               117            186
#
#      Scrambling  SG:AroundTheGreen  Rough Proximity  Birdie/Better_125-150  \
# 123         164                 41               40                     79
#
#      Total
# 123   1742

# %%
#save as csv
df_predictions.to_csv( "predictions.csv")

# %%
df_predictions.reset_index(drop=True)
# Out:
#                  Player  SGoffTheTee  SGteeToGreen  Par3 Scoring_Avergage  \
# 0           Chez Reavie           48            40                      4
# 1       Emiliano Grillo           25            24                      8
# 2       Kevin Streelman           22            15                    108
# 3         Jordan Spieth           18             2                     52
# 4           Justin Rose           21            30                     92
# 5         Rickie Fowler           63            28                     58
# 6          Zach Johnson           89            23                      3
# 7           Austin Cook           77            87                      6
# 8          Brian Harman           60            81                    132
# 9     Bryson DeChambeau           14            12                    113
# 10           Chris Kirk          102            31                     21
# 11         Russell Knox           81            53                    135
# 12         Martin Laird           94            62                    136
# 13             Jon Rahm            2            25                     47
# 14            Ben Crane          177           147                     55
# 15         Beau Hossler           52           110                     60
# 16          Joel Dahmen           76           109                    101
# 17       Chesson Hadley           99            32                      9
# 18         Webb Simpson           95            33                     77
# 19      Brandt Snedeker          122           116                     78
# 20          Adam Hadwin          108            34                     59
# 21       Rory Sabbatini           70            67                    141
# 22           Aaron Wise           33            58                    110
# 23          Matt Kuchar          134            91                    118
# 24        Vaughn Taylor          107            93                     66
# 25            Pat Perez           79            60                     75
# 26             John Huh          111           112                     20
# 27         Scott Piercy           65            11                    122
# 28         Brian Stuard          156           132                     95
# 29             C.T. Pan           74            94                    121
# ..                  ...          ...           ...                    ...
# 78        Jonathan Byrd          178           130                     68
# 79      Charley Hoffman           55            54                    172
# 80      Scott Stallings          146           101                     65
# 81            Bill Haas          129            75                     70
# 82      Brandon Harkins           72            71                     33
# 83          Scott Brown          166           166                     84
# 84       Grayson Murray           35            59                    154
# 85       Anirban Lahiri          123           150                     74
# 86   Tyrone Van Aswegen          181           145                     15
# 87           Kevin Tway           59            80                    126
# 88            Sam Burns           69           106                    148
# 89       Aaron Baddeley          167            61                    112
# 90        Ben Silverman          144           164                    142
# 91        Shawn Stefani          160           126                     79
# 92      Jhonattan Vegas           62            96                    166
# 93            Danny Lee          176           165                     13
# 94         Stewart Cink          100            69                    168
# 95         Chris Stroud          191           172                    163
# 96      Robert Garrigus          121            82                     31
# 97         Tom Lovelady           17           123                    188
# 98         Wesley Bryan          208           193                     99
# 99        Martin Piller          145           191                    123
# 100            Whee Kim          198           200                    152
# 101       Martin Flores          130           125                     86
# 102        Cody Gribble          171           195                    181
# 103           Sung Kang          188           176                     34
# 104        Robert Streb          192           167                    192
# 105      Derek Fathauer          197           197                     44
# 106    Mackenzie Hughes          151           153                    200
# 107      Smylie Kaufman          207           208                    208
#
#      Par4 Scoring_Avergage  Ball Striking  Driving Accuracy  Total Putting  \
# 0                       11            129                 9             68
# 1                       17             21                51             74
# 2                       16             18                60            330
# 3                        8             51               255            394
# 4                        7             36               249            162
# 5                        5             39               165            300
# 6                       20            276               228            148
# 7                       74            243               129             20
# 8                       19            111                63            184
# 9                       30             30               240            172
# 10                      61            225               171            208
# 11                      34             72               108            308
# 12                      63            177               210            138
# 13                       6             75               387            134
# 14                      42            375                54             34
# 15                      45            156               345            108
# 16                      29            162                87            316
# 17                      18            210               411             10
# 18                      12            399               342              8
# 19                      51            345               105            130
# 20                      44            201               174            142
# 21                      36            297               246            168
# 22                      27             96               270            104
# 23                      21            327               231             92
# 24                     105            291                69            144
# 25                      22             45                30            366
# 26                      78            342               144             28
# 27                      14            138               186            398
# 28                      88            279                12             90
# 29                     117             42                42            262
# ..                     ...            ...               ...            ...
# 78                     110            411               372            370
# 79                      60            351               543            294
# 80                     119            534               561            156
# 81                     145            474               501            328
# 82                      96            372               606            284
# 83                      72            423               330            200
# 84                      83            306               486            362
# 85                     129            456               354            212
# 86                     154            528               471            106
# 87                     153            258               570            258
# 88                     109            348               609              6
# 89                      54            576               585            358
# 90                     180            477               219            174
# 91                     151            492               558            122
# 92                     136            408               432            386
# 93                     171            540               285             82
# 94                      56            324               525            288
# 95                     166            555               225            240
# 96                     126            300               510            406
# 97                     113            261               567            278
# 98                     139            600               489             54
# 99                     185            582               438            176
# 100                    170            579               420             96
# 101                    142            468               564            384
# 102                    177            489               483            114
# 103                    194            519               492            236
# 104                    186            570               549            302
# 105                    197            618               600            256
# 106                    146            564               468            346
# 107                    208            603               624            264
#
#      Scrambling  SG:AroundTheGreen  Rough Proximity  Birdie/Better_125-150  \
# 0            26                130               56                     21
# 1           100                129              200                      1
# 2            20                 43                4                    124
# 3             6                 13               13                      4
# 4            52                 54               67                     53
# 5            12                 26              180                     12
# 6            84                 29               51                      7
# 7            86                 44               31                    169
# 8           178                112                5                     37
# 9           200                106               60                     59
# 10           22                 21               87                     91
# 11          142                 58               70                     55
# 12          136                 18               26                     84
# 13          152                 68               94                    163
# 14           60                 64               59                    102
# 15          138                 74               11                     73
# 16           62                118               12                    134
# 17          244                122               18                     44
# 18            2                 24              153                     78
# 19           38                 63              116                     62
# 20          256                 22               45                    154
# 21           58                 19                9                    143
# 22          274                116              106                     64
# 23           66                 71               19                     96
# 24          106                113               92                    110
# 25          366                 85              160                     15
# 26          176                140              145                     34
# 27          246                 90               25                     67
# 28          212                103              103                    107
# 29          322                105               28                    184
# ..          ...                ...              ...                    ...
# 78          134                 14               69                    181
# 79          314                142               38                     17
# 80           56                102               71                    139
# 81          124                 31              105                     93
# 82          250                155              107                     50
# 83          210                 96              181                    173
# 84          326                 89               54                    148
# 85          252                 62              150                    155
# 86          222                 55              149                    126
# 87          318                139              109                     89
# 88          330                196              185                     54
# 89           42                  2               55                    149
# 90          278                149              193                     47
# 91          116                 75              126                    185
# 92          150                156              188                     18
# 93          342                133              164                    150
# 94          382                191               16                    117
# 95          148                141              158                     80
# 96          338                153              114                     72
# 97          378                204               36                    118
# 98          264                 40              171                     38
# 99          196                145               81                    122
# 100         234                174              186                      6
# 101         288                143              104                    200
# 102         386                138              207                    133
# 103         374                152              205                    141
# 104         362                 48              178                     45
# 105         334                125               49                    192
# 106         370                181              156                     90
# 107         408                202               46                    121
#
#      Total
# 0      542
# 1      650
# 2      760
# 3      816
# 4      823
# 5      888
# 6      958
# 7      966
# 8      982
# 9     1036
# 10    1040
# 11    1116
# 12    1144
# 13    1153
# 14    1169
# 15    1172
# 16    1206
# 17    1217
# 18    1223
# 19    1226
# 20    1239
# 21    1254
# 22    1258
# 23    1266
# 24    1296
# 25    1303
# 26    1330
# 27    1362
# 28    1377
# 29    1391
# ..     ...
# 78    2037
# 79    2040
# 80    2050
# 81    2075
# 82    2096
# 83    2101
# 84    2102
# 85    2117
# 86    2152
# 87    2159
# 88    2160
# 89    2161
# 90    2167
# 91    2190
# 92    2198
# 93    2221
# 94    2236
# 95    2239
# 96    2253
# 97    2283
# 98    2295
# 99    2384
# 100   2415
# 101   2634
# 102   2674
# 103   2711
# 104   2791
# 105   2809
# 106   2825
# 107   3099
#
# [108 rows x 13 columns]

# %%
df_predictions.loc[df_predictions['Player'] == "Kevin Na"]
# Out:
#       Player  SGoffTheTee  SGteeToGreen  Par3 Scoring_Avergage  \
# 62  Kevin Na          189            63                     25
#
#     Par4 Scoring_Avergage  Ball Striking  Driving Accuracy  Total Putting  \
# 62                    100            447               153            158
#
#     Scrambling  SG:AroundTheGreen  Rough Proximity  Birdie/Better_125-150  \
# 62          18                  1              175                    132
#
#     Total
# 62   1461

# %%
#field strength
def scrape_owgr(url):
  response = requests.get(url)
  soup = BeautifulSoup(response.content, 'lxml')
  ranks = []
  for item in soup.findAll("td", "name"):
      ranks.append(item.text)
  return ranks

# %%
owgr = scrape_owgr("http://www.owgr.com/ranking")
columns = ['Player']
df_owgr = pd.DataFrame(owgr,columns=columns)

df_owgr.insert(1, 'Rank', range(1, 1 + len(df_owgr)))
df_owgr_field = pd.concat([df_owgr.set_index('Player'),field.set_index('Player')], axis=1, join='inner').reset_index()
#add all the ranks
Total = df_owgr_field['Rank'].sum()
avgRank = Total / len(df_owgr_field.index)
#print the avg rank for the field
print(avgRank.round())
#shows some level of strength of field, could be good to see whether players perform if other good players playing
#only considers top 100 ranked players though
# Out:
# 49.0
