# %%
#import packages required
import requests
import pandas as pd
from bs4 import BeautifulSoup
import csv
import numpy as np
from functools import reduce
import urllib
import urllib.request as ur

# %%
#categories of stats available 

categories = {"Off the tee":"ROTT","Approach the green":"RAPP","Around the green":"RARG","Putting":"RPUT",
              'Scoring':"RSCR","Streaks":"RSTR","Money/Finishes":"RMNY","Points/Rankings":"RPTS"}
print ("Breakdown of statistics categories:")
for key in categories:
    print (key)
# Out:
# Breakdown of statistics categories:
# Off the tee
# Approach the green
# Around the green
# Putting
# Scoring
# Streaks
# Money/Finishes
# Points/Rankings

# %%
def category_links(category):
    
    pga_link = "http://www.pgatour.com/stats/categories."+categories[category]+"_INQ.html"
    pga_link = ur.urlopen(pga_link)
    soup = BeautifulSoup(pga_link,'lxml')
    links = []
    clean_links = {}

    for element in soup.find_all('div',class_="table-content clearfix"):
        for link in element.findAll('a'):
            test = link.get('href')
            clean_links[link.find(text=True)] = test.replace("/content/pgatour", "http://www.pgatour.com")

    return clean_links;

# %%
#input your category and will return stats available with corresponding link
#enter catregory in inverted commas, eg "Scoring"

category_links("Approach the green")
# Out:
# {'Approach 100-125 yards (RTP Score)': 'http://www.pgatour.com/stats/stat.028.html',
#  'Approach 125-150 yards (RTP Score)': 'http://www.pgatour.com/stats/stat.473.html',
#  'Approach 150-175 yards (RTP Score)': 'http://www.pgatour.com/stats/stat.478.html',
#  'Approach 175-200 yards (RTP Score)': 'http://www.pgatour.com/stats/stat.479.html',
#  'Approach 200-225 yards (RTP)': 'http://www.pgatour.com/stats/stat.02376.html',
#  'Approach 225-250 yards (RTP)': 'http://www.pgatour.com/stats/stat.02377.html',
#  'Approach 250-275 yards (RTP)': 'http://www.pgatour.com/stats/stat.02378.html',
#  'Approach 50-75 yards (RTP Score)': 'http://www.pgatour.com/stats/stat.030.html',
#  'Approach 75-100 yards (RTP Score)': 'http://www.pgatour.com/stats/stat.029.html',
#  'Approach < 125 yards (RTP Score)': 'http://www.pgatour.com/stats/stat.472.html',
#  'Approach > 200 yards (RTP Score)': 'http://www.pgatour.com/stats/stat.480.html',
#  'Approach > 275 yards (RTP)': 'http://www.pgatour.com/stats/stat.02379.html',
#  'Approaches 100-125 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02382.html',
#  'Approaches 125-150 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02384.html',
#  'Approaches 150-175 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02385.html',
#  'Approaches 175-200 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02386.html',
#  'Approaches 200-225 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02390.html',
#  'Approaches 225-250 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02391.html',
#  'Approaches 250-275 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02392.html',
#  'Approaches 50-125 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02383.html',
#  'Approaches 50-75 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02380.html',
#  'Approaches 75-100 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02381.html',
#  'Approaches < 100 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02388.html',
#  'Approaches > 100 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02389.html',
#  'Approaches > 200 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02387.html',
#  'Approaches > 275 yards-Rgh (RTP)': 'http://www.pgatour.com/stats/stat.02393.html',
#  'Approaches Left Rough (RTP Score)': 'http://www.pgatour.com/stats/stat.469.html',
#  'Approaches Right Rough (RTP Score)': 'http://www.pgatour.com/stats/stat.470.html',
#  'Approaches from 100-125 yards': 'http://www.pgatour.com/stats/stat.074.html',
#  'Approaches from 100-125 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02364.html',
#  'Approaches from 125-150 yards': 'http://www.pgatour.com/stats/stat.339.html',
#  'Approaches from 125-150 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02366.html',
#  'Approaches from 150-175 yards': 'http://www.pgatour.com/stats/stat.338.html',
#  'Approaches from 150-175 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02367.html',
#  'Approaches from 175-200 yards': 'http://www.pgatour.com/stats/stat.337.html',
#  'Approaches from 175-200 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02368.html',
#  'Approaches from 200-225 yards': 'http://www.pgatour.com/stats/stat.02358.html',
#  'Approaches from 200-225 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02372.html',
#  'Approaches from 225-250 yards': 'http://www.pgatour.com/stats/stat.02359.html',
#  'Approaches from 225-250 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02373.html',
#  'Approaches from 250-275 yards': 'http://www.pgatour.com/stats/stat.02360.html',
#  'Approaches from 250-275 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02374.html',
#  'Approaches from 50-125 yards': 'http://www.pgatour.com/stats/stat.340.html',
#  'Approaches from 50-125 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02365.html',
#  'Approaches from 50-75 yards': 'http://www.pgatour.com/stats/stat.076.html',
#  'Approaches from 50-75 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02362.html',
#  'Approaches from 75-100 yards': 'http://www.pgatour.com/stats/stat.075.html',
#  'Approaches from 75-100 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02363.html',
#  'Approaches from > 100 yards': 'http://www.pgatour.com/stats/stat.02331.html',
#  'Approaches from > 100 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02371.html',
#  'Approaches from > 200 yards': 'http://www.pgatour.com/stats/stat.336.html',
#  'Approaches from > 200 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02369.html',
#  'Approaches from > 275 yards': 'http://www.pgatour.com/stats/stat.02361.html',
#  'Approaches from > 275 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02375.html',
#  'Approaches from inside 100 yards': 'http://www.pgatour.com/stats/stat.02329.html',
#  'Approaches from inside 100 yards (Rgh)': 'http://www.pgatour.com/stats/stat.02370.html',
#  'Average Approach Distance - Birdie or Better': 'http://www.pgatour.com/stats/stat.02338.html',
#  'Average Approach Distance - Bogey or Worse': 'http://www.pgatour.com/stats/stat.02340.html',
#  'Average Approach Distance - Par': 'http://www.pgatour.com/stats/stat.02339.html',
#  'Average Approach Shot Distance': 'http://www.pgatour.com/stats/stat.02325.html',
#  'Average Distance after Going for it Shot': 'http://www.pgatour.com/stats/stat.02431.html',
#  'Average Distance to Hole After Tee Shot': 'http://www.pgatour.com/stats/stat.02430.html',
#  'Average Going for it Shot Distance (in Yards)': 'http://www.pgatour.com/stats/stat.02426.html',
#  'Birdie or Better Percentage - 125-150 ya': 'http://www.pgatour.com/stats/stat.360.html',
#  'Birdie or Better Percentage - 150-175 ya': 'http://www.pgatour.com/stats/stat.359.html',
#  'Birdie or Better Percentage - 175-200 ya': 'http://www.pgatour.com/stats/stat.358.html',
#  'Birdie or Better Percentage - 200+ yards': 'http://www.pgatour.com/stats/stat.357.html',
#  'Birdie or Better Percentage - < 125 yard': 'http://www.pgatour.com/stats/stat.361.html',
#  'Birdie or Better Percentage - Fairway': 'http://www.pgatour.com/stats/stat.02333.html',
#  'Birdie or Better Percentage - Left Rough': 'http://www.pgatour.com/stats/stat.02334.html',
#  'Birdie or Better Percentage - Right Rough': 'http://www.pgatour.com/stats/stat.02335.html',
#  'Birdie or Better Percentage - Rough': 'http://www.pgatour.com/stats/stat.02336.html',
#  'Fairway Approach (RTP Score)': 'http://www.pgatour.com/stats/stat.471.html',
#  'Fairway Proximity': 'http://www.pgatour.com/stats/stat.431.html',
#  'GIR Pct. - Fairway Bunker': 'http://www.pgatour.com/stats/stat.02434.html',
#  'GIR Percentage - 100+ yards': 'http://www.pgatour.com/stats/stat.02332.html',
#  'GIR Percentage - 100-125 yards': 'http://www.pgatour.com/stats/stat.077.html',
#  'GIR Percentage - 125-150 yards': 'http://www.pgatour.com/stats/stat.329.html',
#  'GIR Percentage - 150-175 yards': 'http://www.pgatour.com/stats/stat.328.html',
#  'GIR Percentage - 175-200 yards': 'http://www.pgatour.com/stats/stat.327.html',
#  'GIR Percentage - 200+ yards': 'http://www.pgatour.com/stats/stat.326.html',
#  'GIR Percentage - 75-100 yards': 'http://www.pgatour.com/stats/stat.078.html',
#  'GIR Percentage - < 100 yards': 'http://www.pgatour.com/stats/stat.02330.html',
#  'GIR Percentage - < 125 yards': 'http://www.pgatour.com/stats/stat.330.html',
#  'GIR Percentage - < 75 yards': 'http://www.pgatour.com/stats/stat.079.html',
#  'GIR Percentage from Fairway': 'http://www.pgatour.com/stats/stat.190.html',
#  'GIR Percentage from Other than Fairway': 'http://www.pgatour.com/stats/stat.199.html',
#  'Going for the Green': 'http://www.pgatour.com/stats/stat.419.html',
#  'Going for the Green - Birdie or Better': 'http://www.pgatour.com/stats/stat.02357.html',
#  'Going for the Green - Hit Green Pct.': 'http://www.pgatour.com/stats/stat.486.html',
#  'Greens in Regulation Percentage': 'http://www.pgatour.com/stats/stat.103.html',
#  'Greens or Fringe in Regulation': 'http://www.pgatour.com/stats/stat.02437.html',
#  'Left Rough Proximity': 'http://www.pgatour.com/stats/stat.432.html',
#  'Longest Hole Outs (in yards)': 'http://www.pgatour.com/stats/stat.351.html',
#  'Par 5 Going for the Green': 'http://www.pgatour.com/stats/stat.436.html',
#  'Proximity to Hole': 'http://www.pgatour.com/stats/stat.331.html',
#  'Right Rough Proximity': 'http://www.pgatour.com/stats/stat.433.html',
#  'Rough Proximity': 'http://www.pgatour.com/stats/stat.437.html',
#  'SG: Approach-the-Green': 'http://www.pgatour.com/stats/stat.02568.html',
#  'Total Hole Outs': 'http://www.pgatour.com/stats/stat.350.html'}

# %%
#put all urls for the stats in here
urls = [ 
    "https://www.pgatour.com/stats/stat.02567.html", 
    "https://www.pgatour.com/stats/stat.02674.html",
    "https://www.pgatour.com/stats/stat.142.html",
    "http://www.pgatour.com/stats/stat.143.html",
    "http://www.pgatour.com/stats/stat.158.html",
    "https://www.pgatour.com/stats/stat.102.html",
    "https://www.pgatour.com/stats/stat.02428.html",
    "https://www.pgatour.com/stats/stat.130.html",
    "https://www.pgatour.com/stats/stat.02569.html",
    "https://www.pgatour.com/stats/stat.437.html",
    "https://www.pgatour.com/stats/stat.360.html"]

#these are the names of the stats, just copy and paste these into columnNames below
stats = [ 'SGoffTheTee','SGteeToGreen',"Par3 Scoring_Avergage",
         "Par4 Scoring_Avergage","Ball Striking","Driving Accuracy",
         "Total Putting","Scrambling", "SG:AroundTheGreen",
         "Rough Proximity","Birdie/Better_125-150"]

columnNames = [ "Player",'SGoffTheTee',  'SGteeToGreen',
         "Par3 Scoring_Avergage","Par4 Scoring_Avergage","Ball Striking",
        "Driving Accuracy","Total Putting","Scrambling",
        "SG:AroundTheGreen","Rough Proximity","Birdie/Better_125-150"]
#weights need to be in the correct order for the stats above
weights = [1,1,1,1,3,3,2,2,1,1,1]

stats
# Out:
# ['SGoffTheTee',
#  'SGteeToGreen',
#  'Par3 Scoring_Avergage',
#  'Par4 Scoring_Avergage',
#  'Ball Striking',
#  'Driving Accuracy',
#  'Total Putting',
#  'Scrambling',
#  'SG:AroundTheGreen',
#  'Rough Proximity',
#  'Birdie/Better_125-150']

# %%
#function to call the players name and associated rank for each stat
def scrape_money_leaders(url):
  response = requests.get(url)
  soup = BeautifulSoup(response.content, 'lxml')
  money = []
  for item in soup.findAll("td", "player-name"):
      money.append(item.text)
  return money

# %%
#empty array dfs which will store a dataframe for each stat
dfs = []

for i in range(0,len(urls)):
    stats[i] = scrape_money_leaders(urls[i])
    columns = ['Player']
    stats[i] = pd.DataFrame(stats[i],columns=columns)
    stats[i].insert(1, 'Rank', range(1, 1 + len(stats[i])))
    dfs.append(stats[i])

#then merge each of the dataframes on the equality of the player name
#this means each player will have their name, then their associcated stats in one dataframe
df_final = reduce(lambda left,right: pd.merge(left,right,on='Player'), dfs)
df_final.columns = columnNames

#this loops throguh each feature and multiplies by by the relevant weight
for i in range(1, len(columnNames)-1):
    df_final[columnNames[i]] = df_final[columnNames[i]]*weights[i-1]

#add the contents of each column to give a total for each player
df_final['Total'] = df_final.sum(axis=1)

#sorts these totals so the lowest totals are at the top
df_stats = df_final.sort_values(by='Total', ascending=True)
df_stats = df_stats.replace(to_replace=r'\n', value='', regex=True)

# %%
#temporary scrape of field list - will look to generalise this
field_link = "http://www.deananddelucainvitational.com/players/committed-players"
field_page = ur.urlopen(field_link)
field_soup = BeautifulSoup(field_page,'lxml')

player_list = field_soup.find_all("span", class_="field-content")

field =[]

for player in  player_list:
    field.append(player.text)
    
field = pd.DataFrame(data=field)
field.columns = ["Player"]

field = field.replace(to_replace=r'  ', value=' ', regex=True)

# %%
#stats of players playing in the event
df_predictions = pd.merge(field,df_stats,on="Player")
df_predictions = df_predictions.sort_values(by='Total', ascending=True)
df_predictions
# Out:
#                  Player  SGoffTheTee  SGteeToGreen  Par3 Scoring_Avergage  \
# 28      Emiliano Grillo           28            26                      2
# 77          Chez Reavie           45            39                     20
# 79          Justin Rose           15             7                     90
# 96      Kevin Streelman           25            23                    115
# 92        Jordan Spieth           18             2                     38
# 22        Rickie Fowler           69            38                     52
# 45           Chris Kirk           94            29                     26
# 13          Austin Cook           75            84                      5
# 33         Brian Harman           50            78                    137
# 16    Bryson DeChambeau           12            11                    105
# 14            Ben Crane          168           124                    103
# 48         Russell Knox           73            44                    121
# 76             Jon Rahm            2            21                     76
# 15          Joel Dahmen           74            96                    104
# 40         Zach Johnson          103            31                     15
# 31          Adam Hadwin           90            33                     70
# 37         Beau Hossler           48           115                     73
# 70            Pat Perez           78            97                     58
# 90      Brandt Snedeker          119           106                     77
# 52          Matt Kuchar          127            76                    140
# 80       Rory Sabbatini           66            55                    144
# 30       Chesson Hadley          100            30                     13
# 100       Vaughn Taylor          104            88                     62
# 54         Martin Laird           95            60                    141
# 88         Webb Simpson           96            32                     91
# 1           Ryan Armour          113            65                     64
# 98         Brian Stuard          144           129                     94
# 39             John Huh          110           102                     14
# 108          Aaron Wise           32            59                    100
# 73          J.T. Poston           42            75                     10
# ..                  ...          ...           ...                    ...
# 102          Kevin Tway           47            67                     97
# 89        Cameron Smith          131           100                    158
# 103  Tyrone Van Aswegen          180           132                     21
# 56            Danny Lee          164           152                     17
# 68         Rod Pampling          134           159                    157
# 93      Scott Stallings          142           105                     92
# 94        Shawn Stefani          154           117                     61
# 99          Nick Taylor          111           140                     95
# 32      Brandon Harkins           62            82                     24
# 63       Grayson Murray           31            70                    164
# 7         Jonathan Byrd          182           137                     65
# 11         Stewart Cink           92            58                    159
# 49      Satoshi Kodaira           86           178                    154
# 104     Jhonattan Vegas           60            98                    147
# 4           Scott Brown          160           171                     81
# 2        Aaron Baddeley          172            71                    117
# 59         Tom Lovelady           19           122                    183
# 97         Chris Stroud          192           173                    167
# 43             Whee Kim          198           197                    109
# 25      Robert Garrigus          121            90                     43
# 5          Wesley Bryan          206           190                    118
# 6             Sam Burns           70           142                    133
# 72        Martin Piller          156           195                    114
# 21        Martin Flores          143           127                     68
# 20       Derek Fathauer          197           192                     42
# 27         Cody Gribble          170           194                    182
# 38     Mackenzie Hughes          135           135                    198
# 95         Robert Streb          191           166                    185
# 41            Sung Kang          189           187                     44
# 42       Smylie Kaufman          204           206                    206
#
#      Par4 Scoring_Avergage  Ball Striking  Driving Accuracy  Total Putting  \
# 28                      12             33                51             28
# 77                      11            135                 9            100
# 79                       2             21               231            150
# 96                      18             12                54            326
# 92                       8             60               300            374
# 22                       7             81               189            180
# 45                      45            207               174            204
# 13                      94            243               126             26
# 33                      14            126                63            134
# 16                      21             27               243            222
# 14                      19            354                48             38
# 48                      33             75               111            342
# 76                       3             48               387            138
# 15                      20            147               105            306
# 40                      32            339               279            160
# 31                      30            162               159            156
# 37                      44            153               339             88
# 70                      23             45                33            218
# 90                      35            372               120            112
# 52                      22            261               210             84
# 80                      25            309               264            162
# 30                      13            198               411             10
# 100                     87            270                66            124
# 54                      63            189               234            188
# 88                      17            390               342             16
# 1                       92            219                 6            310
# 98                      71            267                15             74
# 39                      79            327               150             40
# 108                     39            117               288            118
# 73                      86            129               252            302
# ..                     ...            ...               ...            ...
# 102                    135            240               573            270
# 89                      53            483               483            338
# 103                    136            510               471             92
# 56                     163            525               267             62
# 68                     179            411               153            368
# 93                     120            543               555            186
# 94                     151            429               540            144
# 99                     168            318               294            298
# 32                     112            342               597            292
# 63                      85            303               477            354
# 7                      124            426               423            358
# 11                      76            276               480            284
# 49                     161            324               135            290
# 104                    154            423               435            372
# 4                       93            453               324            212
# 2                       56            576               591            360
# 59                      99            249               561            296
# 97                     152            561               249            238
# 43                     172            585               414             48
# 25                     127            336               522            396
# 5                      140            603               504             98
# 6                      169            375               612              6
# 72                     186            579               462            132
# 21                     156            495               570            366
# 20                     188            612               594            206
# 27                     178            489               492            130
# 38                     129            552               450            362
# 95                     181            570               552            280
# 41                     197            540               498            224
# 42                     206            594               618            250
#
#      Scrambling  SG:AroundTheGreen  Rough Proximity  Birdie/Better_125-150  \
# 28           78                121              196                      1
# 77           50                141               72                      8
# 79           46                 47               26                     29
# 96           28                 67                3                    115
# 92           12                  8                8                      5
# 22           14                 35              160                     23
# 45           20                 38               62                     63
# 13           96                 43               28                    166
# 33          222                128                5                     30
# 16          162                 95               44                     66
# 14           32                 61               21                     59
# 48          128                 45               71                     45
# 76          206                 62               95                     55
# 15           56                116               14                     85
# 40           88                 20               47                     18
# 31          238                 42               37                    117
# 37          132                 75               24                     72
# 70          368                114              146                      3
# 90           54                 44               80                     71
# 52           72                 70               17                    114
# 80           66                 11               11                     83
# 30          252                117               10                     48
# 100         104                101               82                    145
# 54          152                 25               33                     60
# 88            4                 19              164                     80
# 1           164                 18               89                    118
# 98          188                 96               81                    116
# 39          168                133              126                     33
# 108         248                105              121                     78
# 73          236                 56              103                     31
# ..          ...                ...              ...                    ...
# 102         292                132               91                     88
# 89           64                 27               29                    176
# 103         182                 55              134                    130
# 56          298                113              145                    161
# 68          228                161               43                     84
# 93           62                104               73                    105
# 94          130                 80               93                    194
# 99          214                109              199                    152
# 32          290                168              100                     50
# 63          336                 93               59                    164
# 7           160                 23               51                    198
# 11          364                192               22                    146
# 49          402                206              163                     73
# 104         122                151              179                     39
# 4           244                 87              186                    177
# 2            44                  2               68                    137
# 59          374                199               20                     91
# 97          140                138              158                     81
# 43          176                169              181                      7
# 25          342                149              117                     65
# 5           280                 65              122                     28
# 6           372                203              182                     93
# 72          218                147               75                    102
# 21          312                130              102                    199
# 20          322                129               30                    171
# 27          380                140              205                    128
# 38          354                174              148                    113
# 95          328                 53              170                     76
# 41          378                164              202                    141
# 42          406                198               61                    162
#
#      Total
# 28     576
# 77     630
# 79     664
# 96     786
# 92     833
# 22     848
# 45     962
# 13     986
# 33     987
# 16    1008
# 14    1027
# 48    1088
# 76    1093
# 15    1123
# 40    1132
# 31    1134
# 37    1163
# 70    1183
# 90    1190
# 52    1193
# 80    1196
# 30    1202
# 100   1233
# 54    1240
# 88    1251
# 1     1258
# 98    1275
# 39    1282
# 108   1305
# 73    1322
# ..     ...
# 102   2032
# 89    2042
# 103   2043
# 56    2067
# 68    2077
# 93    2087
# 94    2093
# 99    2098
# 32    2119
# 63    2136
# 7     2147
# 11    2149
# 49    2172
# 104   2180
# 4     2188
# 2     2194
# 59    2213
# 97    2249
# 43    2256
# 25    2308
# 5     2354
# 6     2357
# 72    2366
# 21    2668
# 20    2683
# 27    2688
# 38    2750
# 95    2752
# 41    2764
# 42    3111
#
# [110 rows x 13 columns]

# %%
#add odds to the table
def scrape_money_leaders(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'lxml')
    return soup

oddsScrape = scrape_money_leaders("https://m.skybet.com/golf/memorial/event/22317959")

#players
players = oddsScrape.findAll("b", "cell-text__line")

playerNames = []

for player in players:
    playerNames.append(player.text)

df_players = pd.DataFrame(data=playerNames)
df_players.columns = ["Player"]

#odds
odds = oddsScrape.findAll("span", "js-oc-price")

playerOdds = []

for odd in odds:
    playerOdds.append(odd.text)

df_odds = pd.DataFrame(data=playerOdds)
df_odds.columns = ["Odds"]
df_odds = df_odds.replace(to_replace=r'\n            ', value='', regex=True)

#odds and players
odd_players = pd.concat([df_players, df_odds], axis=1, join='inner')

df_predictions1 = pd.merge(df_predictions, odd_players, on="Player")
df_predictions1
# Out:
#                Player  SGoffTheTee  SGteeToGreen  Par3 Scoring_Avergage  \
# 0     Emiliano Grillo           28            26                      2
# 1         Justin Rose           15             7                     90
# 2     Kevin Streelman           25            23                    115
# 3       Jordan Spieth           18             2                     38
# 4       Rickie Fowler           69            38                     52
# 5          Chris Kirk           94            29                     26
# 6         Austin Cook           75            84                      5
# 7        Russell Knox           73            44                    121
# 8        Zach Johnson          103            31                     15
# 9         Adam Hadwin           90            33                     70
# 10       Beau Hossler           48           115                     73
# 11          Pat Perez           78            97                     58
# 12        Matt Kuchar          127            76                    140
# 13     Rory Sabbatini           66            55                    144
# 14     Chesson Hadley          100            30                     13
# 15       Martin Laird           95            60                    141
# 16        Ryan Armour          113            65                     64
# 17       Brian Stuard          144           129                     94
# 18           John Huh          110           102                     14
# 19         Aaron Wise           32            59                    100
# 20           Kevin Na          183            40                      9
# 21         Adam Scott           34             9                    129
# 22       Jason Kokrak           44            54                      7
# 23     Russell Henley          101           110                    107
# 24         Alex Cejka           93            56                     66
# 25          Jim Furyk          177           118                     84
# 26   Louis Oosthuizen           30            63                    113
# 27    Patrick Cantlay           11            17                     82
# 28      Andrew Landry           43           108                     54
# 29       Kevin Kisner          163           165                     53
# ..                ...          ...           ...                    ...
# 33        Nick Watney           58            93                     98
# 34        Sean O'Hair           64           119                    195
# 35    Patrick Rodgers          146           162                     46
# 36  Xander Schauffele           37            50                    127
# 37           Tom Hoge          115            74                     72
# 38     Patton Kizzire          157           101                     34
# 39      Abraham Ancer           99           111                     80
# 40      Brice Garnett           57           139                    119
# 41    David Lingmerth          120           182                    194
# 42        Kelly Kraft          188           174                    122
# 43    Charley Hoffman           55            69                    162
# 44          Bill Haas          130            61                     69
# 45     Anirban Lahiri          112           145                     74
# 46         Si Woo Kim           17            53                    139
# 47         Kevin Tway           47            67                     97
# 48      Cameron Smith          131           100                    158
# 49          Danny Lee          164           152                     17
# 50       Rod Pampling          134           159                    157
# 51    Brandon Harkins           62            82                     24
# 52     Grayson Murray           31            70                    164
# 53       Stewart Cink           92            58                    159
# 54    Satoshi Kodaira           86           178                    154
# 55    Jhonattan Vegas           60            98                    147
# 56        Scott Brown          160           171                     81
# 57           Whee Kim          198           197                    109
# 58       Wesley Bryan          206           190                    118
# 59          Sam Burns           70           142                    133
# 60      Martin Piller          156           195                    114
# 61   Mackenzie Hughes          135           135                    198
# 62       Robert Streb          191           166                    185
#
#     Par4 Scoring_Avergage  Ball Striking  Driving Accuracy  Total Putting  \
# 0                      12             33                51             28
# 1                       2             21               231            150
# 2                      18             12                54            326
# 3                       8             60               300            374
# 4                       7             81               189            180
# 5                      45            207               174            204
# 6                      94            243               126             26
# 7                      33             75               111            342
# 8                      32            339               279            160
# 9                      30            162               159            156
# 10                     44            153               339             88
# 11                     23             45                33            218
# 12                     22            261               210             84
# 13                     25            309               264            162
# 14                     13            198               411             10
# 15                     63            189               234            188
# 16                     92            219                 6            310
# 17                     71            267                15             74
# 18                     79            327               150             40
# 19                     39            117               288            118
# 20                     66            408               177            176
# 21                    104              3               225            388
# 22                     62            156               510             96
# 23                     97             87                60             90
# 24                    107            459               144            288
# 25                    126            516                45             76
# 26                     52            369               312            266
# 27                     42            111               360            332
# 28                     47            405               351            126
# 29                     81            300                81             14
# ..                    ...            ...               ...            ...
# 33                     89            237               546             34
# 34                    118            297               303             86
# 35                    166            291               390             36
# 36                    102            294               429            256
# 37                    113            507               285            312
# 38                     46            288               564             70
# 39                     73            432               330            278
# 40                    144            201               147            328
# 41                    130            519                87             94
# 42                    162            468               240            106
# 43                     61            363               525            244
# 44                    111            504               516            300
# 45                    114            456               369            232
# 46                    145            438               327            276
# 47                    135            240               573            270
# 48                     53            483               483            338
# 49                    163            525               267             62
# 50                    179            411               153            368
# 51                    112            342               597            292
# 52                     85            303               477            354
# 53                     76            276               480            284
# 54                    161            324               135            290
# 55                    154            423               435            372
# 56                     93            453               324            212
# 57                    172            585               414             48
# 58                    140            603               504             98
# 59                    169            375               612              6
# 60                    186            579               462            132
# 61                    129            552               450            362
# 62                    181            570               552            280
#
#     Scrambling  SG:AroundTheGreen  Rough Proximity  Birdie/Better_125-150  \
# 0           78                121              196                      1
# 1           46                 47               26                     29
# 2           28                 67                3                    115
# 3           12                  8                8                      5
# 4           14                 35              160                     23
# 5           20                 38               62                     63
# 6           96                 43               28                    166
# 7          128                 45               71                     45
# 8           88                 20               47                     18
# 9          238                 42               37                    117
# 10         132                 75               24                     72
# 11         368                114              146                      3
# 12          72                 70               17                    114
# 13          66                 11               11                     83
# 14         252                117               10                     48
# 15         152                 25               33                     60
# 16         164                 18               89                    118
# 17         188                 96               81                    116
# 18         168                133              126                     33
# 19         248                105              121                     78
# 20          18                  1              178                     98
# 21         276                 41              162                     46
# 22         232                119               57                     90
# 23         392                200              144                     49
# 24          22                  5               52                    147
# 25          34                 26              105                    151
# 26          10                 14               25                    205
# 27         226                 31              195                    138
# 28         124                184                4                    104
# 29         302                108              108                    184
# ..         ...                ...              ...                    ...
# 33         268                176               19                    108
# 34         148                173              113                    140
# 35         196                 58              198                     99
# 36         144                 89              147                    120
# 37          58                 92              123                     47
# 38         294                142               35                     74
# 39          70                143               46                    185
# 40         216                183              140                    193
# 41         234                186              106                     16
# 42         178                187               63                     77
# 43         318                144               34                     13
# 44          98                 17               74                    122
# 45         212                 49              149                     97
# 46         310                 37              139                    133
# 47         292                132               91                     88
# 48          64                 27               29                    176
# 49         298                113              145                    161
# 50         228                161               43                     84
# 51         290                168              100                     50
# 52         336                 93               59                    164
# 53         364                192               22                    146
# 54         402                206              163                     73
# 55         122                151              179                     39
# 56         244                 87              186                    177
# 57         176                169              181                      7
# 58         280                 65              122                     28
# 59         372                203              182                     93
# 60         218                147               75                    102
# 61         354                174              148                    113
# 62         328                 53              170                     76
#
#     Total           Odds
# 0     576   45/1
# 1     664   14/1
# 2     786  125/1
# 3     833   18/1
# 4     848   20/1
# 5     962  125/1
# 6     986  200/1
# 7    1088  125/1
# 8    1132   80/1
# 9    1134  100/1
# 10   1163  100/1
# 11   1183  125/1
# 12   1193   35/1
# 13   1196  125/1
# 14   1202   70/1
# 15   1240  175/1
# 16   1258  250/1
# 17   1275  300/1
# 18   1282  250/1
# 19   1305   70/1
# 20   1354   50/1
# 21   1417   50/1
# 22   1427  150/1
# 23   1437  125/1
# 24   1439  400/1
# 25   1458  250/1
# 26   1459   50/1
# 27   1545   66/1
# 28   1550  200/1
# 29   1559   80/1
# ..    ...            ...
# 33   1726  150/1
# 34   1756  250/1
# 35   1788  250/1
# 36   1795   80/1
# 37   1798  300/1
# 38   1805  300/1
# 39   1847  300/1
# 40   1867  250/1
# 41   1868  175/1
# 42   1965  400/1
# 43   1988  125/1
# 44   2002  100/1
# 45   2009  175/1
# 46   2014  150/1
# 47   2032  150/1
# 48   2042  100/1
# 49   2067  100/1
# 50   2077  500/1
# 51   2119  300/1
# 52   2136  175/1
# 53   2149  300/1
# 54   2172  200/1
# 55   2180  250/1
# 56   2188  400/1
# 57   2256  500/1
# 58   2354  400/1
# 59   2357  250/1
# 60   2366  400/1
# 61   2750  400/1
# 62   2752  300/1
#
# [63 rows x 14 columns]

# %%
df_predictions.isnull().any().any()
# Out:
# False

# %%
#players in the field we dont have stats for
field_players = set(field["Player"])
stats_players = set(df_stats["Player"])

print(field_players - stats_players)
# Out:
# {'Steve Stricker', 'Brooks Koepka', 'Tim Herron', 'Shubhankar Sharma', 'Ted Potter Jr.', 'Joaquin Niemann', 'John Senden', 'David     Hearn', 'Keith Clearwater', 'Maverick McNealy', 'J. J. Henry'}

# %%
#search for player within field
df_predictions.loc[df_predictions['Player'] == "Brooks Koepka"]
# Out:
# Empty DataFrame
# Columns: [Player, SGoffTheTee, SGteeToGreen, Par3 Scoring_Avergage, Par4 Scoring_Avergage, Ball Striking, Driving Accuracy, Total Putting, Scrambling, SG:AroundTheGreen, Rough Proximity, Birdie/Better_125-150, Total]
# Index: []

# %%
#search for player outside of field
df_stats.loc[df_stats['Player'] == "Ted Potter, Jr."]
# Out:
#               Player  SGoffTheTee  SGteeToGreen  Par3 Scoring_Avergage  \
# 115  Ted Potter, Jr.          116           103                    177
#
#      Par4 Scoring_Avergage  Ball Striking  Driving Accuracy  Total Putting  \
# 115                    148            471               117            242
#
#      Scrambling  SG:AroundTheGreen  Rough Proximity  Birdie/Better_125-150  \
# 115         138                 24               36                     70
#
#      Total
# 115   1642

# %%
#save as csv
df_predictions.to_csv( "predictions.csv")

# %%
df_predictions.reset_index(drop=True)
# Out:
#                  Player  SGoffTheTee  SGteeToGreen  Par3 Scoring_Avergage  \
# 0       Emiliano Grillo           28            26                      2
# 1           Chez Reavie           45            39                     20
# 2           Justin Rose           15             7                     90
# 3       Kevin Streelman           25            23                    115
# 4         Jordan Spieth           18             2                     38
# 5         Rickie Fowler           69            38                     52
# 6            Chris Kirk           94            29                     26
# 7           Austin Cook           75            84                      5
# 8          Brian Harman           50            78                    137
# 9     Bryson DeChambeau           12            11                    105
# 10            Ben Crane          168           124                    103
# 11         Russell Knox           73            44                    121
# 12             Jon Rahm            2            21                     76
# 13          Joel Dahmen           74            96                    104
# 14         Zach Johnson          103            31                     15
# 15          Adam Hadwin           90            33                     70
# 16         Beau Hossler           48           115                     73
# 17            Pat Perez           78            97                     58
# 18      Brandt Snedeker          119           106                     77
# 19          Matt Kuchar          127            76                    140
# 20       Rory Sabbatini           66            55                    144
# 21       Chesson Hadley          100            30                     13
# 22        Vaughn Taylor          104            88                     62
# 23         Martin Laird           95            60                    141
# 24         Webb Simpson           96            32                     91
# 25          Ryan Armour          113            65                     64
# 26         Brian Stuard          144           129                     94
# 27             John Huh          110           102                     14
# 28           Aaron Wise           32            59                    100
# 29          J.T. Poston           42            75                     10
# ..                  ...          ...           ...                    ...
# 80           Kevin Tway           47            67                     97
# 81        Cameron Smith          131           100                    158
# 82   Tyrone Van Aswegen          180           132                     21
# 83            Danny Lee          164           152                     17
# 84         Rod Pampling          134           159                    157
# 85      Scott Stallings          142           105                     92
# 86        Shawn Stefani          154           117                     61
# 87          Nick Taylor          111           140                     95
# 88      Brandon Harkins           62            82                     24
# 89       Grayson Murray           31            70                    164
# 90        Jonathan Byrd          182           137                     65
# 91         Stewart Cink           92            58                    159
# 92      Satoshi Kodaira           86           178                    154
# 93      Jhonattan Vegas           60            98                    147
# 94          Scott Brown          160           171                     81
# 95       Aaron Baddeley          172            71                    117
# 96         Tom Lovelady           19           122                    183
# 97         Chris Stroud          192           173                    167
# 98             Whee Kim          198           197                    109
# 99      Robert Garrigus          121            90                     43
# 100        Wesley Bryan          206           190                    118
# 101           Sam Burns           70           142                    133
# 102       Martin Piller          156           195                    114
# 103       Martin Flores          143           127                     68
# 104      Derek Fathauer          197           192                     42
# 105        Cody Gribble          170           194                    182
# 106    Mackenzie Hughes          135           135                    198
# 107        Robert Streb          191           166                    185
# 108           Sung Kang          189           187                     44
# 109      Smylie Kaufman          204           206                    206
#
#      Par4 Scoring_Avergage  Ball Striking  Driving Accuracy  Total Putting  \
# 0                       12             33                51             28
# 1                       11            135                 9            100
# 2                        2             21               231            150
# 3                       18             12                54            326
# 4                        8             60               300            374
# 5                        7             81               189            180
# 6                       45            207               174            204
# 7                       94            243               126             26
# 8                       14            126                63            134
# 9                       21             27               243            222
# 10                      19            354                48             38
# 11                      33             75               111            342
# 12                       3             48               387            138
# 13                      20            147               105            306
# 14                      32            339               279            160
# 15                      30            162               159            156
# 16                      44            153               339             88
# 17                      23             45                33            218
# 18                      35            372               120            112
# 19                      22            261               210             84
# 20                      25            309               264            162
# 21                      13            198               411             10
# 22                      87            270                66            124
# 23                      63            189               234            188
# 24                      17            390               342             16
# 25                      92            219                 6            310
# 26                      71            267                15             74
# 27                      79            327               150             40
# 28                      39            117               288            118
# 29                      86            129               252            302
# ..                     ...            ...               ...            ...
# 80                     135            240               573            270
# 81                      53            483               483            338
# 82                     136            510               471             92
# 83                     163            525               267             62
# 84                     179            411               153            368
# 85                     120            543               555            186
# 86                     151            429               540            144
# 87                     168            318               294            298
# 88                     112            342               597            292
# 89                      85            303               477            354
# 90                     124            426               423            358
# 91                      76            276               480            284
# 92                     161            324               135            290
# 93                     154            423               435            372
# 94                      93            453               324            212
# 95                      56            576               591            360
# 96                      99            249               561            296
# 97                     152            561               249            238
# 98                     172            585               414             48
# 99                     127            336               522            396
# 100                    140            603               504             98
# 101                    169            375               612              6
# 102                    186            579               462            132
# 103                    156            495               570            366
# 104                    188            612               594            206
# 105                    178            489               492            130
# 106                    129            552               450            362
# 107                    181            570               552            280
# 108                    197            540               498            224
# 109                    206            594               618            250
#
#      Scrambling  SG:AroundTheGreen  Rough Proximity  Birdie/Better_125-150  \
# 0            78                121              196                      1
# 1            50                141               72                      8
# 2            46                 47               26                     29
# 3            28                 67                3                    115
# 4            12                  8                8                      5
# 5            14                 35              160                     23
# 6            20                 38               62                     63
# 7            96                 43               28                    166
# 8           222                128                5                     30
# 9           162                 95               44                     66
# 10           32                 61               21                     59
# 11          128                 45               71                     45
# 12          206                 62               95                     55
# 13           56                116               14                     85
# 14           88                 20               47                     18
# 15          238                 42               37                    117
# 16          132                 75               24                     72
# 17          368                114              146                      3
# 18           54                 44               80                     71
# 19           72                 70               17                    114
# 20           66                 11               11                     83
# 21          252                117               10                     48
# 22          104                101               82                    145
# 23          152                 25               33                     60
# 24            4                 19              164                     80
# 25          164                 18               89                    118
# 26          188                 96               81                    116
# 27          168                133              126                     33
# 28          248                105              121                     78
# 29          236                 56              103                     31
# ..          ...                ...              ...                    ...
# 80          292                132               91                     88
# 81           64                 27               29                    176
# 82          182                 55              134                    130
# 83          298                113              145                    161
# 84          228                161               43                     84
# 85           62                104               73                    105
# 86          130                 80               93                    194
# 87          214                109              199                    152
# 88          290                168              100                     50
# 89          336                 93               59                    164
# 90          160                 23               51                    198
# 91          364                192               22                    146
# 92          402                206              163                     73
# 93          122                151              179                     39
# 94          244                 87              186                    177
# 95           44                  2               68                    137
# 96          374                199               20                     91
# 97          140                138              158                     81
# 98          176                169              181                      7
# 99          342                149              117                     65
# 100         280                 65              122                     28
# 101         372                203              182                     93
# 102         218                147               75                    102
# 103         312                130              102                    199
# 104         322                129               30                    171
# 105         380                140              205                    128
# 106         354                174              148                    113
# 107         328                 53              170                     76
# 108         378                164              202                    141
# 109         406                198               61                    162
#
#      Total
# 0      576
# 1      630
# 2      664
# 3      786
# 4      833
# 5      848
# 6      962
# 7      986
# 8      987
# 9     1008
# 10    1027
# 11    1088
# 12    1093
# 13    1123
# 14    1132
# 15    1134
# 16    1163
# 17    1183
# 18    1190
# 19    1193
# 20    1196
# 21    1202
# 22    1233
# 23    1240
# 24    1251
# 25    1258
# 26    1275
# 27    1282
# 28    1305
# 29    1322
# ..     ...
# 80    2032
# 81    2042
# 82    2043
# 83    2067
# 84    2077
# 85    2087
# 86    2093
# 87    2098
# 88    2119
# 89    2136
# 90    2147
# 91    2149
# 92    2172
# 93    2180
# 94    2188
# 95    2194
# 96    2213
# 97    2249
# 98    2256
# 99    2308
# 100   2354
# 101   2357
# 102   2366
# 103   2668
# 104   2683
# 105   2688
# 106   2750
# 107   2752
# 108   2764
# 109   3111
#
# [110 rows x 13 columns]

# %%
df_predictions.loc[df_predictions['Player'] == "Kevin Na"]
# Out:
#       Player  SGoffTheTee  SGteeToGreen  Par3 Scoring_Avergage  \
# 64  Kevin Na          183            40                      9
#
#     Par4 Scoring_Avergage  Ball Striking  Driving Accuracy  Total Putting  \
# 64                     66            408               177            176
#
#     Scrambling  SG:AroundTheGreen  Rough Proximity  Birdie/Better_125-150  \
# 64          18                  1              178                     98
#
#     Total
# 64   1354

# %%
#field strength
def scrape_owgr(url):
  response = requests.get(url)
  soup = BeautifulSoup(response.content, 'lxml')
  ranks = []
  for item in soup.findAll("td", "name"):
      ranks.append(item.text)
  return ranks

# %%
owgr = scrape_owgr("http://www.owgr.com/ranking")
columns = ['Player']
df_owgr = pd.DataFrame(owgr,columns=columns)

df_owgr.insert(1, 'Rank', range(1, 1 + len(df_owgr)))
df_owgr_field = pd.concat([df_owgr.set_index('Player'),field.set_index('Player')], axis=1, join='inner').reset_index()
#add all the ranks
Total = df_owgr_field['Rank'].sum()
avgRank = Total / len(df_owgr_field.index)
#print the avg rank for the field
print(avgRank.round())
#shows some level of strength of field, could be good to see whether players perform if other good players playing
#only considers top 100 ranked players though
# Out:
# 49.0
